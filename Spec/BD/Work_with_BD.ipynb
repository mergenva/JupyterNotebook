# %%
import pymysql # py -3 -m pip install pymysql

# %%
pymysql.connect?
# Out:
# Init signature:
# pymysql.connect(
#     *,
#     user=None,
#     password='',
#     host=None,
#     database=None,
#     unix_socket=None,
#     port=0,
#     charset='',
#     collation=None,
#     sql_mode=None,
#     read_default_file=None,
#     conv=None,
#     use_unicode=True,
#     client_flag=0,
#     cursorclass=<class 'pymysql.cursors.Cursor'>,
#     init_command=None,
#     connect_timeout=10,
#     read_default_group=None,
#     autocommit=False,
#     local_infile=False,
#     max_allowed_packet=16777216,
#     defer_connect=False,
#     auth_plugin_map=None,
#     read_timeout=None,
#     write_timeout=None,
#     bind_address=None,
#     binary_prefix=False,
#     program_name=None,
#     server_public_key=None,
#     ssl=None,
#     ssl_ca=None,
#     ssl_cert=None,
#     ssl_disabled=None,
#     ssl_key=None,
#     ssl_key_password=None,
#     ssl_verify_cert=None,
#     ssl_verify_identity=None,
#     compress=None,
#     named_pipe=None,
#     passwd=None,
# ...

# %%
connection = pymysql.connect(
    user='u2015135_python',
    password='qB2gA9xZ5rkY1jW9',
    database='u2015135_default',
    host='server125.hosting.reg.ru', # либо url server125.hosting.reg.ru
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 connection = pymysql.connect(
#       2     user='u2015135_python',
#       3     password='qB2gA9xZ5rkY1jW9',
#       4     database='u2015135_default',
#       5     host='server125.hosting.reg.ru', # либо url server125.hosting.reg.ru
#       6 )
#
# ...
