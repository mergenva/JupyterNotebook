# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('schetX.xlsx', sheet_name='Артикулы')
df
# Out:
#          артикул                                     товары  Кол-во  цена  \
# 0  2037478335240          KARINGBEE Швейные машины FHSM-505      60  2500
# 1  6970237663870            SOOCAS Бритва Электрическая S32      61  2501
# 2  6974706560004  YUNMAI Массажер YMFG-B563 (PRO с кнопкой)      62  2502
# 3  6955578034626                      DEERMA Пылесос DX115C      63  2503
#
#     сумма
# 0  150000
# 1  150001
# 2  150002
# 3  150003

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   артикул  4 non-null      int64
#  1   товары   4 non-null      object
#  2   Кол-во   4 non-null      int64
#  3   цена     4 non-null      int64
#  4   сумма    4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 292.0+ bytes

# %%
artikuls = df['артикул']
artikuls_list = []
for el in artikuls:
    artikuls_list.append(el)
print(artikuls_list)
# Out:
# [2037478335240, 6970237663870, 6974706560004, 6955578034626]

# %%
df = pd.read_excel('palet.xlsx', sheet_name='Паллетизация')
df
# Out:
#     Код основного EAN БЕИ  Цена  Код второго EAN БЕИ  \
# 0           6955578034626   NaN                  NaN
# 1           6955578034619   NaN                  NaN
# 2           6955578033858   NaN                  NaN
# 3           6955578034992   NaN                  NaN
# 4           6955578041945   NaN                  NaN
# ..                    ...   ...                  ...
# 56          6970237665546   NaN                  NaN
# 57          6955578043222   NaN                  NaN
# 58          6955578043239   NaN                  NaN
# 59          6955578043260   NaN                  NaN
# 60          6955578042768   NaN                  NaN
#
#                                    Наименование из 1С  Код материала  \
# 0                               DEERMA Пылесос DX115C      400154438
# 1                               DEERMA Пылесос DX118C       20082889
# 2                                DEERMA Пылесос DX700      400154578
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Код основного EAN БЕИ     61 non-null     int64
#  1   Цена                      0 non-null      float64
#  2   Код второго EAN БЕИ       2 non-null      float64
#  3   Наименование из 1С        61 non-null     object
#  4   Код материала             61 non-null     int64
#  5   Код материала поставщика  53 non-null     object
#  6   Текст инфо-записи         53 non-null     object
#  7   Длина БЕИ                 53 non-null     float64
#  8   Ширина БЕИ                53 non-null     float64
#  9   Высота БЕИ                53 non-null     float64
#  10  Вес брутто                53 non-null     float64
#  11  Код основного EAN БЕИ.1   53 non-null     float64
#  12  Код второго EAN БЕИ.1     4 non-null      float64
# ...

# %%
df.head()
# Out:
#    Код основного EAN БЕИ  Цена  Код второго EAN БЕИ        Наименование из 1С  \
# 0          6955578034626   NaN                  NaN     DEERMA Пылесос DX115C
# 1          6955578034619   NaN                  NaN     DEERMA Пылесос DX118C
# 2          6955578033858   NaN                  NaN      DEERMA Пылесос DX700
# 3          6955578034992   NaN                  NaN     DEERMA Пылесос DX700S
# 4          6955578041945   NaN                  NaN  DEERMA Пылесос DX700 Pro
#
#    Код материала Код материала поставщика         Текст инфо-записи  \
# 0      400154438              УТ-00001531     DEERMA Пылесос DX115C
# 1       20082889              УТ-00001538     DEERMA Пылесос DX118C
# 2      400154578              УТ-00000947      DEERMA Пылесос DX700
# 3       20083108              УТ-00001047     DEERMA Пылесос DX700S
# 4      400217762              УТ-00003537  DEERMA Пылесос DX700 Pro
#
#    Длина БЕИ  Ширина БЕИ  Высота БЕИ  ...  Код второго EAN МК  Количество ЕПЛ  \
# ...

# %%
for el in artikuls_list:
    if df['Код основного EAN БЕИ'] == el:
        name = df['Наименование из 1С']
        sapkod = df['Код материала']
        shtrihkodMK = df['Код основного EAN МК']
print(name, sapkod, shtrihkodMK)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_155976/1361877260.py in ?()
#       1 for el in artikuls_list:
# ----> 2     if df['Код основного EAN БЕИ'] == el:
#       3         name = df['Наименование из 1С']
#       4         sapkod = df['Код материала']
#       5         shtrihkodMK = df['Код основного EAN МК']
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
