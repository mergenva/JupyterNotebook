# %% [markdown]
# Задача 4
#
# а) Прочитать Болты.xlsx
#
# б) Найти размеры (диаметр и длина). Размеры могут быть дробные с точкой или запятой, диаметр может быть вида М6. Если размер только один (диаметр) и он начинается с буквы М, тоже надо распознать. Одиночные размеры без буквы М можно игнорировать.
#
# в) Где есть количество в штуках или кг - тоже распознать.
#
# г) Наименование, диаметр, длина, количество, вес - сохранить в виде таблицы (в любом виде)
#
# д*) Используя вторую таблицу "Размеры болтов" посчитать вес болтов, у еоторых указано только количество и наоборот.
