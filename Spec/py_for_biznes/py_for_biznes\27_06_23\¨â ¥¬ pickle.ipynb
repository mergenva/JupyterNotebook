# %%
import pickle

# %%
f = open('скатерти.pickle', 'rb')  # b потому что не текст
data = pickle.load(f)
f.close()

data
# Out:
# [{'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-21ЯК', 'Длина': 220, 'Ширина': 150},
#  {'Артикул': 'арт.07С-21ЯК', 'Длина': 220, 'Ширина': 150},
#  {'Артикул': 'арт.Обр.1761ЯК', 'Длина': 229, 'Ширина': 170},
#  {'Артикул': 'арт.14С-18ЯК', 'Длина': 50, 'Ширина': 50},
#  {'Артикул': 'арт.14С-18', 'Длина': 50, 'Ширина': 50},
#  {'Артикул': 'арт.7С-128ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.7С-128ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 70, 'Ширина': 50},
# ...
