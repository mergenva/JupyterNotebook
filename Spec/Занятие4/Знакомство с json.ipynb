# %%
import json

# %%
f = open('Погода.json', 'rt')
data1 = json.load(f)

# %%
type(data1)
# Out:
# dict

# %%
data1['data'][0]['tmax']*10 # числа
# Out:
# -40

# %%
data1
# Out:
# {'data': [{'date': '2021-01-29',
#    'prcp': None,
#    'pres': None,
#    'snow': None,
#    'tavg': -6.7,
#    'tmax': -4,
#    'tmin': -9,
#    'tsun': None,
#    'wdir': None,
#    'wpgt': None,
#    'wspd': None},
#   {'date': '2021-01-30',
#    'prcp': None,
#    'pres': None,
#    'snow': None,
#    'tavg': -4.6,
#    'tmax': 0,
#    'tmin': -8,
#    'tsun': None,
#    'wdir': None,
#    'wpgt': None,
#    'wspd': None},
#   {'date': '2021-01-31',
#    'prcp': None,
#    'pres': None,
#    'snow': None,
#    'tavg': -5.1,
#    'tmax': -3,
#    'tmin': -7,
#    'tsun': None,
#    'wdir': None,
#    'wpgt': None,
#    'wspd': None},
#   {'date': '2021-02-01',
#    'prcp': None,
#    'pres': None,
#    'snow': None,
#    'tavg': -1,
#    'tmax': 1,
#    'tmin': -6,
#    'tsun': None,
#    'wdir': None,
#    'wpgt': None,
#    'wspd': None},
#   {'date': '2021-02-02',
#    'prcp': None,
#    'pres': None,
#    'snow': None,
#    'tavg': -0.1,
#    'tmax': 1,
#    'tmin': -1,
# ...

# %%
json_text = """
{"widget": {
    "debug": "on",
    "window": {
        "title": "Sample Konfabulator Widget",
        "name": "main_window",
        "width": 500,
        "height": 500
    },
    "image": { 
        "src": "Images/Sun.png",
        "name": "sun1",
        "hOffset": 250,
        "vOffset": 250,
        "alignment": "center"
    },
    "text": {
        "data": "Click Here",
        "size": 36,
        "style": "bold",
        "name": "text1",
        "hOffset": 250,
        "vOffset": 100,
        "alignment": "center",
        "onMouseUp": "sun1.opacity = (sun1.opacity / 100) * 90;"
    }
}}    
"""

# %%
data2 = json.loads(json_text)
data2
# Out:
# {'widget': {'debug': 'on',
#   'window': {'title': 'Sample Konfabulator Widget',
#    'name': 'main_window',
#    'width': 500,
#    'height': 500},
#   'image': {'src': 'Images/Sun.png',
#    'name': 'sun1',
#    'hOffset': 250,
#    'vOffset': 250,
#    'alignment': 'center'},
#   'text': {'data': 'Click Here',
#    'size': 36,
#    'style': 'bold',
#    'name': 'text1',
#    'hOffset': 250,
#    'vOffset': 100,
#    'alignment': 'center',
#    'onMouseUp': 'sun1.opacity = (sun1.opacity / 100) * 90;'}}}

# %%
import pickle
f2 = open('../Занятие3/скатерти.pickle', 'rb')
data3 = pickle.load(f2)
f2.close()

# %%
data3
# Out:
# [{'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-21ЯК', 'Длина': 150, 'Ширина': 220},
#  {'Артикул': 'арт.07С-21ЯК', 'Длина': 150, 'Ширина': 220},
#  {'Артикул': 'арт.Обр.1761ЯК', 'Длина': 170, 'Ширина': 229},
#  {'Артикул': 'арт.14С-18ЯК', 'Длина': 50, 'Ширина': 50},
#  {'Артикул': 'арт.14С-18', 'Длина': 50, 'Ширина': 50},
#  {'Артикул': 'арт.7С-128ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.7С-128ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
#  {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70},
# ...

# %%
str(data3) # не совсем подойдет
# Out:
# "[{'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-21ЯК', 'Длина': 150, 'Ширина': 220}, {'Артикул': 'арт.07С-21ЯК', 'Длина': 150, 'Ширина': 220}, {'Артикул': 'арт.Обр.1761ЯК', 'Длина': 170, 'Ширина': 229}, {'Артикул': 'арт.14С-18ЯК', 'Длина': 50, 'Ширина': 50}, {'Артикул': 'арт.14С-18', 'Длина': 50, 'Ширина': 50}, {'Артикул': 'арт.7С-128ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.7С-128ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.07С-39ЯК', 'Длина': 50, 'Ширина': 70}, {'Артикул': 'арт.0С-53', 'Длина': None, 'Ширина': None}, {'Артикул': 'арт.0С-43ЯК', 'Длина': 1
# ...

# %%
# ensure_ascii для русских букв
# indent для отсупов
json_text2 = json.dumps(data3, ensure_ascii=False, indent=2)
print(json_text2)
# Out:
# [
#   {
#     "Артикул": "арт.07С-39ЯК",
#     "Длина": 50,
#     "Ширина": 70
#   },
#   {
#     "Артикул": "арт.07С-39ЯК",
#     "Длина": 50,
#     "Ширина": 70
#   },
#   {
#     "Артикул": "арт.07С-39ЯК",
#     "Длина": 50,
#     "Ширина": 70
#   },
#   {
#     "Артикул": "арт.07С-39ЯК",
#     "Длина": 50,
#     "Ширина": 70
#   },
#   {
#     "Артикул": "арт.07С-39ЯК",
#     "Длина": 50,
#     "Ширина": 70
#   },
#   {
#     "Артикул": "арт.07С-21ЯК",
#     "Длина": 150,
#     "Ширина": 220
#   },
#   {
#     "Артикул": "арт.07С-21ЯК",
#     "Длина": 150,
#     "Ширина": 220
#   },
#   {
#     "Артикул": "арт.Обр.1761ЯК",
#     "Длина": 170,
#     "Ширина": 229
#   },
#   {
#     "Артикул": "арт.14С-18ЯК",
#     "Длина": 50,
#     "Ширина": 50
#   },
#   {
#     "Артикул": "арт.14С-18",
#     "Длина": 50,
#     "Ширина": 50
#   },
#   {
#     "Артикул": "арт.7С-128ЯК",
#     "Длина": 50,
#     "Ширина": 70
#   },
#   {
#     "Артикул": "арт.7С-128ЯК",
#     "Длина": 50,
# ...

# %%
f3 = open('Скатерти.json', 'wt', encoding='utf-8')
json.dump(data3, f3, ensure_ascii=False, indent=2) # кладем обычный словарь
f3.close()
